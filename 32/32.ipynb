# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
req=requests.get('https://www.flipkart.com/boat-wave-flex-connect-1-83-hd-display-bluetooth-calling-premium-metal-design-smartwatch/p/itm8541a93a7e868?pid=SMWGMNNYKU5HDHGU&lid=LSTSMWGMNNYKU5HDHGURCY0PK&marketplace=FLIPKART&store=ajy%2Fbuh&srno=b_1_8&otracker=browse&fm=organic&iid=en_0QHVdMR6Vl%2B%2FPW3%2BQjU7191HzjhTv4Jz8Z3FNHZFnFtafaXmd5LHEAOyLsPf%2FD6jK6chuU0b91kQZtQhwNCbHA%3D%3D&ppt=browse&ppn=browse&ssid=aahifamz400000001685262964040')
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
req.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soup=bs(req.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
rating=soup.find('div',{'class':'_2d4LTz'}).get_text()
print(rating)
# Out:
# 4.1

# %%
comments=soup.find_all('p',{'class':'_2-N8zT'})
for comment in comments:
    print(comment.get_text()+"\n\n")
# Out:
# Very Good
#
#
# Pretty good
#
#
# Really Nice
#
#
# Awesome
#
#
# Highly recommended
#
#
# Must buy!
#
#
# Unsatisfactory
#
#
# Must buy!
#
#
# Value-for-money
#
#
# Simply awesome

# %%
reviews=soup.findAll('div',{'class':'t-ZTKy'})
for review in reviews:
    print(review.get_text()+"\n\n")
# Out:
# Product is very good .... display is top notch .Battery is best in this price range like literally best .. although the display ratio should have been like 1.9 because watch is big compared toh it's display size... overall good product only one thing missing is calculator i don't know why they haven't installed it😂..I think they forgot to add it but u can go for the watch it's good...and lastly the strap quality can be better in this prize range ..but it has very cool boat logo which looks ...READ MORE
#
#
# Overall Watch is Excellent 👌... Every features are Awesome 👍... (1)Still I Face Minor Issues like there is no change in cloud watch face gallery...(2) one issue i also face is the Weather Panel is Not updating my cities location...Still Worth every Money I gave...I am a genuine Buyer of Flipkart So i am highly recommend this watch... Thanks 😊👍READ MORE
#
#
# ...

# %%
ratin=soup.find_all('div',{'class':'_3LWZlK _1BLPMq'})
for rat in ratin:
    print(rat.get_text()+"\n\n")
# Out:
# 4
#
#
# 4
#
#
# 4
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5

# %%
cust=soup.find_all('div',{'class':'_2sc7ZR _2V5EHH'})
for c in cust:
    print(c.get_text()+"\n\n")
# Out:
# 4
#
#
# 4
#
#
# 4
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5
#
#
# 5

# %%
data={
    "name"
}
